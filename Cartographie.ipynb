# %% [markdown]
# | <img src="img/logo_cartographie.png" width="60px" height="60px" > | <td bgcolor="orange">SCIENCES NUMÉRIQUES ET TECHNOLOGIE</td> | **LOCALISATION - CARTOGRAPHIE** |<td bgcolor="orange" style="color:white;"> $\Large{2^{nde}}$ </td>|
# | --- |  :---: | :---: | :---: |

# %%
from IPython.display import display, IFrame, Javascript
from ipywidgets import Box,Dropdown,HTML,VBox,Image,Label,Text,Textarea,HBox,Layout,GridspecLayout,FileUpload,Button
# Permet de tout executer au lancement du notebook + conserver le notebook actif pendant 2h
from masquer import *

display(Javascript("""
function repeter(){
IPython.notebook.kernel.execute("a=1");
}
// execute a = 1 en python toutes les 8 minutes pendant 2h
let timerId = setInterval(() => repeter(), 480000);
setTimeout(() => { clearInterval(timerId); alert('fin de cession'); }, 7200000);

// Supprimer la taille limite pour la sortie d'une cellule
IPython.OutputArea.prototype._should_scroll = function(lines) {
    return false;
};
IPython.notebook.kernel.execute("url = '" + window.location + "'");"""))

f = FileUpload(
    description = "CHARGER",
    accept='.snt',  # Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
    multiple=False  # True to accept multiple files upload else False
)

bou = Button(
    description='SAUVER',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='SAUVER',
    icon='' # (FontAwesome names without the `fa-` prefix)
)

save = {}
save_state = {}
saved_widgets = {}
charge = False

def sauver_etats(b=None):
    global save_state,save,saved_widgets,charge
    if not charge:
        k = saved_widgets.keys()
        for val in k:
            save_state[val]=saved_widgets[val].value
        save['Cartographie']=save_state
        with open('SAVE.snt', 'w') as out:
            out.write(str(save))
    
def charger_etats(b=None):
    global save_state,saved_widgets,save,charge
    charge=True
    with open('SAVE.snt', 'a') as file:
        pass
    with open('SAVE.snt', 'r') as file:
        save2 = {}
        try:
            save2=eval(file.read())
        except:
            pass
    save = save2
    save_state2 = {}
    try:
        save_state2=save2['Cartographie']
    except:
        pass
    k = save_state2.keys()
    for val in k:
        if save_state2[val] != '':
            save_state[val] = save_state2[val]
    k = save_state.keys()
    for val in k:
        try:
            saved_widgets[val].value = save_state[val]
        except:
            pass
    save['Cartographie'] = save_state
    charge = False 
    sauver_etats()
    
    
def on_click(b):
    url = "../notebooks/SAVE.snt"
    display(Javascript('window.open("{url}");'.format(url=url)))
         
def on_use(b):
    global save_state
    if f.data ==[]:
        return
    
    with open("SAVE.snt", "w+b") as i:
        i.write(f.data[0])
    charger_etats()
    f.data = []

display(HTML("<h1 style='text-align:center;'>PERSONNALISATION DE VOTRE LIVRE NUMERIQUE</h1>"))
display(HBox([bou,f],layout=Layout(width='100%',justify_content="center")))

    
bou.on_click(on_click)  
f.observe(on_use,"data")
# Out:
# <h1 style='text-align:center;'>PERSONNALISATION DE VOTRE LIVRE NUMERIQUE</h1>
# ...

# %% [markdown]
# ## Vidéos à regarder
# ***

# %%
HTML("""<iframe width="100%" height="300" src="https://www.youtube.com/embed/ez1xZWpY9NE?start=21" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>""")
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="100%" height="300" src="https://www.youtube.com/embed/ez1xZWpY9NE?start=21" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
HTML("""<iframe width="100%" height="300" src="https://www.youtube.com/embed/iTfNhcC2vBA" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>""")
# Out:
# <iframe width="100%" height="300" src="https://www.youtube.com/embed/iTfNhcC2vBA" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
HTML("""<iframe width="100%" height="300" src="https://www.youtube.com/embed/BiFevsDtUYQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>""")
# Out:
# <iframe width="100%" height="300" src="https://www.youtube.com/embed/BiFevsDtUYQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
HTML("""<iframe width="100%" height="300" src="https://www.youtube.com/embed/WoqpQbWdacQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>""")
# Out:
# <iframe width="100%" height="300" src="https://www.youtube.com/embed/WoqpQbWdacQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
HTML("""<iframe width="100%" height="300" src="https://www.youtube.com/embed/e79tSIpLiDk" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>""")
# Out:
# <iframe width="100%" height="300" src="https://www.youtube.com/embed/e79tSIpLiDk" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Repères historiques
# ***

# %%
grid = GridspecLayout(3, 4,width='100%', height='350px',layout=Layout(justify_items='center',align_items='center'))
saved_widgets['repere1']=Text(layout=Layout(width="80%",align_items="center"))
grid[0,0]=saved_widgets['repere1']
saved_widgets['repere2']=Text(layout=Layout(width="80%",align_items="center"))
grid[0,1]=saved_widgets['repere2']
saved_widgets['repere3']=Text(layout=Layout(width="80%",align_items="center"))
grid[0,2]=saved_widgets['repere3']
saved_widgets['repere4']=Text(layout=Layout(width="80%",align_items="center"))
grid[0,3]=saved_widgets['repere4']
grid[1,0]=Image(value=open("img/gps.png","rb").read(),format="png", width="95%")
grid[1,1]=Image(value=open("img/carte.png","rb").read(),format="png",width="95%")
grid[1,2]=Image(value=open("img/galileo.png","rb").read(),format="png",width="95%")
grid[1,3]=Image(value=open("img/earth.png","rb").read(),format="png",width="95%")
grid[2,0]=Label(value="$1^{er}$ système GPS américain")
grid[2,1]=Label(value="$1^{ere}$ carte géographique sur le web")
grid[2,2]=Label(value="Déploiement de Galileo")
grid[2,3]=Label(value="Google Earth")
grid
# Out:
# GridspecLayout(children=(Text(value='', layout=Layout(align_items='center', grid_area='widget001', width='80%'…

# %% [markdown]
# Les cartes ont été systématiquement numérisées à la fin du XXe siècle.
#
#
# Le principal instrument de localisation, GPS (Global Positioning System), a été conçu par l’armée américaine. Le premier satellite GPS fut lancé **en 1978**. Il y en a actuellement **une trentaine**, de sorte qu’à tout moment **quatre à six satellites au moins** sont visibles depuis tout point de la Terre. Couplé aux cartes numériques le système **GPS** permet de se situer. Il n’est pas toujours efficace en ville et peut être complété par d’autres moyens de localisation comme la détection de bornes Wi-Fi proches.
#
#
# D’autres systèmes plus précis, dont **Galileo**, sont en cours de déploiement.

# %% [markdown]
# ## Se positionner sur la terre
# ***

# %% [markdown]
# Etudiez les deux documents suivants puis compléter le texte

# %%
IFrame(src='https://isn-icn-ljm.pagesperso-orange.fr/SNT/localisation/co/module_SNT_loc_5.html', width=950, height=1050)
# Out:
#         <iframe
#             width="950"
#             height="1050"
#             src="https://isn-icn-ljm.pagesperso-orange.fr/SNT/localisation/co/module_SNT_loc_5.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# [![capture](img/sepositionner.png)](http://sciences-ingenieur.genevoix-signoret-vinci.fr/SNT/6-cartographie/co/03_les_coordonnees_geographiques.html "Cliquez pour obtenir la version interactive")

# %% [markdown]
# Les coordonnées géographiques permettent de localiser un lieu sur Terre à l’aide de deux valeurs d’angles appelées **latitude** et **longitude**.

# %%
grid2 = GridspecLayout(2, 2,width='100%', height='400px',layout=Layout(justify_items='center',align_items='center'))
saved_widgets['lat']=Dropdown(options=['Latitude', 'Longitude', ''],
    value='',
    description='',
    disabled=False,layout=Layout(width="60%",align_items="center"))
grid2[0,0]=saved_widgets['lat']
saved_widgets['lon']=Dropdown(options=['Latitude', 'Longitude', ''],
    value='',
    description='',
    disabled=False,layout=Layout(width="60%",align_items="center"))
grid2[0,1]=saved_widgets['lon']
grid2[1,0]=Image(value=open("img/latitude.png","rb").read(),format="png", width="60%")
grid2[1,1]=Image(value=open("img/longitude.png","rb").read(),format="png",width="60%")

grid2
# Out:
# GridspecLayout(children=(Dropdown(index=2, layout=Layout(align_items='center', grid_area='widget001', width='6…

# %%
saved_widgets['equateur']=Text(layout=Layout(width="10%",display="flex",flex_wrap='wrap'))
saved_widgets['greenwich']=Text(layout=Layout(width="10%",display="flex",flex_wrap='wrap'))
display(Label("La valeur de chaque angle est définie par rapport à une référence :"),
        HBox([Label("Le parallèle d’origine est"),
     saved_widgets['equateur'],Label("pour la latitude")]),
HBox([Label("Le méridien d’origine est appelé méridien de"),
     saved_widgets['greenwich'],
     Label("pour la longitude.")]))
# Out:
# Label(value='La valeur de chaque angle est définie par rapport à une référence :')
# ...

# %%
saved_widgets['lat1']=Dropdown(options=['','Latitude', 'Longitude', 'Nord-Sud', 'Est-Ouest','-90°', '90°','-180°','180°' ],
    value='',
    description='',
    disabled=False,layout=Layout(width="max-content",align_items="center"))
saved_widgets['lat2']=Dropdown(options=['','Latitude', 'Longitude', 'Nord-Sud', 'Est-Ouest','-90°', '90°','-180°','180°' ],
    value='',
    description='',
    disabled=False,layout=Layout(width="max-content",align_items="center"))
saved_widgets['lat3']=Dropdown(options=['','Latitude', 'Longitude', 'Nord-Sud', 'Est-Ouest','-90°', '90°','-180°','180°' ],
    value='',
    description='',
    disabled=False,layout=Layout(width="max-content",align_items="center"))
saved_widgets['lat4']=Dropdown(options=['','Latitude', 'Longitude', 'Nord-Sud', 'Est-Ouest','-90°', '90°','-180°','180°' ],
    value='',
    description='',
    disabled=False,layout=Layout(width="max-content",align_items="center"))
saved_widgets['lat5']=Dropdown(options=['','Latitude', 'Longitude', 'Nord-Sud', 'Est-Ouest','-90°', '90°','-180°','180°' ],
    value='',
    description='',
    disabled=False,layout=Layout(width="max-content",align_items="center"))
saved_widgets['lat6']=Dropdown(options=['','Latitude', 'Longitude', 'Nord-Sud', 'Est-Ouest','-90°', '90°','-180°','180°' ],
    value='',
    description='',
    disabled=False,layout=Layout(width="max-content",align_items="center"))
saved_widgets['lat7']=Dropdown(options=['','Latitude', 'Longitude', 'Nord-Sud', 'Est-Ouest','-90°', '90°','-180°','180°' ],
    value='',
    description='',
    disabled=False,layout=Layout(width="max-content",align_items="center"))
saved_widgets['lat8']=Dropdown(options=['','Latitude', 'Longitude', 'Nord-Sud', 'Est-Ouest','-90°', '90°','-180°','180°' ],
    value='',
    description='',
    disabled=False,layout=Layout(width="max-content",align_items="center"))
display(HBox([Label("La"),saved_widgets['lat1'],
             Label('indique le positionnement'),
             saved_widgets['lat2'],Label("d'un point sur Terre."),
             Label("Elle s'étend de"),saved_widgets['lat3'],
             Label('au pôle Sud à'),saved_widgets['lat4'],
             Label('au pôle Nord'),],layout=Layout(flex_flow='row wrap')),
        HBox([Label("La"),saved_widgets['lat5'],
             Label("indique le positionnement"),saved_widgets['lat6'],
             Label("d'un point sur Terre."),
             Label("Elle s'étend de"),saved_widgets['lat7'],
             Label("à l'Ouest à"),saved_widgets['lat8'],
             Label("à l'Est")],layout=Layout(flex_flow='row wrap')))

# %% [markdown]
# ### Exercice

# %%
saved_widgets['coordonnees']=Textarea(layout=Layout(width="90%",align_items="center"))
display(HTML("Quelles sont les coordonnées géographiques de votre lycée ?"),
       saved_widgets['coordonnees'])
# Out:
# Quelles sont les coordonnées géographiques de votre lycée ?
# Textarea(value='', layout=Layout(align_items='center', width='90%'))

# %%
saved_widgets['lieu']=Textarea(layout=Layout(width="90%",align_items="center"))
display(HTML("A quel lieu correspondent ces coordonnées (-12.780701, 45.231619) ?"),
       saved_widgets['lieu'])
# Out:
# A quel lieu correspondent ces coordonnées (-12.780701, 45.231619) ?
# Textarea(value='', layout=Layout(align_items='center', width='90%'))

# %%
saved_widgets['principe_geolocalisation']=Textarea(layout=Layout(width="90%",height="8em",align_items="center"))
display(HTML("Expliquer le principe de la géolocalisation"),
       saved_widgets['principe_geolocalisation'])
# Out:
# Expliquer le principe de la géolocalisation
# Textarea(value='', layout=Layout(align_items='center', height='8em', width='90%'))

# %% [markdown]
# ## Activité Géoportail
# ***

# %% [markdown]
# [![geoportail](img/geoportail.png)](https://www.geoportail.gouv.fr "accéder à géoportail")

# %% [markdown]
# ### Exercice

# %% [markdown]
# À l’aide du site : https://www.geoportail.gouv.fr/ répondre aux questions suivantes:

# %%
saved_widgets['lycee']=Text(layout=Layout(width='50%',margin='0px 0px 20px 0px'))
saved_widgets['surface']=Text(layout=Layout(width='50%',margin='0px 0px 20px 0px'))
saved_widgets['distance']=Text(layout=Layout(width='50%',margin='0px 0px 20px 0px'))

display(HTML("Quelles sont les coordonnées (Latitude/Longitude) de votre lycée ?"),
              saved_widgets['lycee'],
        HTML("Quelle est la superficie du bâtiment principal ?"),
              saved_widgets['surface'],
       HTML("Quelle est la distance entre votre domicile et le lycée ?"),
              saved_widgets['distance'])
# Out:
# Quelles sont les coordonnées (Latitude/Longitude) de votre lycée ?
# Text(value='', layout=Layout(margin='0px 0px 20px 0px', width='50%'))
# Quelle est la superficie du bâtiment principal ?
# Text(value='', layout=Layout(margin='0px 0px 20px 0px', width='50%'))
# Quelle est la distance entre votre domicile et le lycée ?
# Text(value='', layout=Layout(margin='0px 0px 20px 0px', width='50%'))

# %% [markdown]
# ## Activité Python
# ***

# %% [markdown]
# [![capture d'écran activité 1](img/capture_act1.png)](../notebooks/Cartographie/Cartographie_TP_1.ipynb "Cliquez ici pour accéder à l'activité 1")

# %% [markdown]
# ## Les métadonnées d'une photo numérique
# ***

# %%
charger_etats()
k = saved_widgets.keys()
for val in k:
    saved_widgets[val].observe(sauver_etats,"value")
